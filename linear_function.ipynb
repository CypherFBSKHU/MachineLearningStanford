# %% [markdown]
# Code to plot the graph of a linear function

# %%
import matplotlib.pyplot as plt


x = [0, 1, 2, 3, 4, 5]

y = []

for i in x:
  y.append(2*i + 1)

plt.plot(x, y)
plt.title("Graph of y = 2x + 1")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()
